# %%
from UNet import *
# Out:
# Using 'cuda' device.

# %%
training_loader, validation_loader, test_loader = build_dataloaders(batch_size=32)
model = UNet()
loss_func = perceptual_loss
vgg19 = torch.hub.load("chenyaofo/pytorch-cifar-models", "cifar10_vgg19_bn", pretrained=True).cuda()
run_model(model, training_loader, validation_loader, optimizer=Adam, learning_rate=lr, get_output_and_loss=loss_func, nn=vgg19)
visualize(model, "UNet", test_loader)
# Out:
# Using cache found in /home/syu4/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [ 1/10] Train Loss = 0.2158; Valid Loss = 0.1723; Valid Accuracy = 0.0%<p>[ 2/10] Train Loss = 0.1727; Valid Loss = 0.1674; Valid Accuracy = 0.0%<p>[ 3/10] Train Loss = 0.1678; Valid Loss = 0.1606; Valid Accuracy = 0.0%<p>[ 4/10] Train Loss = 0.1595; Valid Loss = 0.1546; Valid Accuracy = 0.0%<p>[ 5/10] Train Loss = 0.1564; Valid Loss = 0.1503; Valid Accuracy = 0.0%<p>[ 6/10] Train Loss = 0.1532; Valid Loss = 0.1579; Valid Accuracy = 0.0%<p>[ 7/10] Train Loss = 0.1536; Valid Loss = 0.1480; Valid Accuracy = 0.0%<p>[ 8/10] Train Loss = 0.1520; Valid Loss = 0.1458; Valid Accuracy = 0.0%<p>[ 9/10] Train Loss = 0.1513; Valid Loss = 0.1463; Valid Accuracy = 0.0%<p>[10/10] Train Loss = 0.1554; Valid Loss = 0.1493; Valid Accuracy = 0.0%
# [10/10] Train Loss = 0.1554; Valid Loss = 0.1493; Valid Accuracy = 0.0%
